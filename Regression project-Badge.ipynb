# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_bf71b2aaab5e4141bd379fd5c105495e = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='qX22hXQ7zXbGF6n2BfCLIj_J3HdDTQHRXWlDXlHU-EVd',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_bf71b2aaab5e4141bd379fd5c105495e.get_object(Bucket='regressionbadge-donotdelete-pr-imahe6z54r8u3p',Key='day.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

#Day = pd.read_csv(body)
#Day.head()


body = client_bf71b2aaab5e4141bd379fd5c105495e.get_object(Bucket='regressionbadge-donotdelete-pr-imahe6z54r8u3p',Key='hour.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

Hour = pd.read_csv(body)
Hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#Feature Selection
Hour = Hour.drop(columns=['dteday','instant'])

# %%
# Normalizing the data
from sklearn import preprocessing
x=Hour.drop(['cnt'],axis=1)
y=Hour['cnt']
x = preprocessing.normalize(x)

# %%
#Splitting the dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train);
y_predicted_r = rf.predict(x_test)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_predicted_r)
mse
# Out:
# 106.26006137322592

# %%
from math import sqrt
rmse = sqrt(mse)
rmse
# Out:
# 10.308252100779546

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test, y_predicted_r)
r
# Out:
# 0.9967838627663451

# %%
print("Mean Squared Error:",mse)
print ("Root Mean Squared Error:", rmse)
print("R score:",r)
# Out:
# Mean Squared Error: 106.26006137322592
# Root Mean Squared Error: 10.308252100779546
# R score: 0.9967838627663451
